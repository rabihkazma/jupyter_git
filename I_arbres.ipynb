# %%
import csv

# %%
with open ('/home/rabih.kazma@Digital-Grenoble.local/Documents/Projet_arbre/I_data/trees.csv', newline='') as f:
    reader=csv.reader(f)
    data=list(reader)
    for ligne in data[0:2]:
        print(ligne)
# Out:
# ['\ufeffELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE', 'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC', 'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE', 'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT', 'EQUIPE', 'REMARQUES', 'ANNEEDEPLANTATION', 'RAISONDEPLANTATION', 'TRAITEMENTCHENILLES', 'COURRIER', 'IDENTIFIANTPLU', 'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU', 'ANNEEABATTAGE', 'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE', 'COLLECTIVITE', 'GeoJSON']
# ['37993', 'ESP37969', 'ESP37969', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP065', "Arbre d'enceintes fermées", 'ESP37898', 'Maison des Collines Jard Poisat', '6', 'AR37969', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '{"type":"Point","coordinates":[5.76034690089422,45.1543159441061]}']

# %%
for ligne in data[0:2]:
    print(ligne[1])   
########ajout commentaire à la fin cellule 3#####################
# Out:
# CODE
# ESP37969

# %%
list_annee=[]
for ligne in data:
    list_annee.append(ligne[19])
list_annee
# Out:
# ['ANNEEDEPLANTATION',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2000',
#  '2017',
#  '2009',
#  '2009',
#  '2009',
#  '1983',
#  '1983',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '2017',
#  '2017',
#  '2017',
# ...

# %%
for ligne in data[0:49]:
    print(ligne)
# Out:
# ['\ufeffELEM_POINT_ID', 'CODE', 'NOM', 'GENRE', 'GENRE_DESC', 'CATEGORIE', 'CATEGORIE_DESC', 'SOUS_CATEGORIE', 'SOUS_CATEGORIE_DESC', 'CODE_PARENT', 'CODE_PARENT_DESC', 'ADR_SECTEUR', 'BIEN_REFERENCE', 'GENRE_BOTA', 'ESPECE', 'VARIETE', 'STADEDEDEVELOPPEMENT', 'EQUIPE', 'REMARQUES', 'ANNEEDEPLANTATION', 'RAISONDEPLANTATION', 'TRAITEMENTCHENILLES', 'COURRIER', 'IDENTIFIANTPLU', 'TYPEIMPLANTATIONPLU', 'INTITULEPROTECTIONPLU', 'ANNEEABATTAGE', 'ESSOUCHEMENT', 'DIAMETREARBRE', 'CAUSEABATTAGE', 'COLLECTIVITE', 'GeoJSON']
# ['37993', 'ESP37969', 'ESP37969', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP065', "Arbre d'enceintes fermées", 'ESP37898', 'Maison des Collines Jard Poisat', '6', 'AR37969', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '{"type":"Point","coordinates":[5.76034690089422,45.1543159441061]}']
# ...

# %%
for ligne in data[-50:-1]:
    print(ligne)
# Out:
# ['21364', 'ESP7304', 'ESP7304', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP174', "Arbre d'espaces ouverts", 'ESP1250', 'Ch Collège accès Pl des Géants', '6', 'AR7304', 'Acer', 'pseudoplatanus', '', 'Arbre adulte', '', '', '1975', '', '', '', '', '', '', '', '', '', '', 'Ville de Grenoble', '{"type":"Point","coordinates":[5.73852344302863,45.1624457240512]}']
# ['14071', 'ESP5616', 'ESP5616', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP174', "Arbre d'espaces ouverts", 'ESP1250', 'Ch Collège accès Pl des Géants', '6', 'AR5616', 'Acer', 'pseudoplatanus', '', 'Arbre adulte', '', '', '1975', '', '', '', '', '', '', '', '', '', '', 'Ville de Grenoble', '{"type":"Point","coordinates":[5.73813789824864,45.1626221637677]}']
# ...

# %%
print(len(data))
# Out:
# 31244

# %%
compte_anne_vide=list_annee.count('')
print("arbres manque-t-il l’information concernant la date de plantation", compte_anne_vide)
# Out:
# arbres manque-t-il l’information concernant la date de plantation 442

# %%
compte_anne_naissance=list_annee.count('1989')
print (compte_anne_naissance)
# Out:
# 307

# %%
b=[int(item) for item in list_annee if (item!='' and item!='ANNEEDEPLANTATION')]
anne_minimum=min(b)
anne_maximal=max(b)
print (anne_minimum,anne_maximal)
# Out:
# 1950 2017

# %%
dico_anne={}
for annee in range (1950,2018):
    #print(annee,":", list_annee.count(str(annee)))
    dico_anne[annee]=list_annee.count(str(annee))
dico_anne
# Out:
# {1950: 422,
#  1951: 0,
#  1952: 0,
#  1953: 0,
#  1954: 0,
#  1955: 66,
#  1956: 0,
#  1957: 0,
#  1958: 0,
#  1959: 0,
#  1960: 745,
#  1961: 27,
#  1962: 0,
#  1963: 0,
#  1964: 7,
#  1965: 760,
#  1966: 95,
#  1967: 57,
#  1968: 116,
#  1969: 350,
#  1970: 1444,
#  1971: 75,
#  1972: 364,
#  1973: 34,
#  1974: 350,
#  1975: 3922,
#  1976: 972,
#  1977: 616,
#  1978: 912,
#  1979: 361,
#  1980: 1528,
#  1981: 644,
#  1982: 448,
#  1983: 333,
#  1984: 666,
#  1985: 990,
#  1986: 238,
#  1987: 771,
#  1988: 266,
#  1989: 307,
#  1990: 433,
#  1991: 146,
#  1992: 226,
#  1993: 161,
#  1994: 288,
#  1995: 781,
#  1996: 385,
#  1997: 238,
#  1998: 220,
#  1999: 603,
#  2000: 461,
#  2001: 1626,
#  2002: 341,
#  2003: 352,
#  2004: 352,
#  2005: 450,
#  2006: 616,
#  2007: 155,
#  2008: 219,
#  2009: 696,
#  2010: 467,
#  2011: 530,
#  2012: 338,
#  2013: 335,
#  2014: 881,
#  2015: 996,
#  2016: 347,
#  2017: 272}

# %%
somme=0
for annee in range (1950,2018):
    #print(annee,":", list_annee.count(str(annee)))
    somme=somme+list_annee.count(str(annee))
print(somme/68)
# Out:
# 452.95588235294116

# %%
sum(dico_anne.values()) / len(dico_anne)
# Out:
# 452.95588235294116

# %%
list(dico_anne.items())
# Out:
# [(1950, 422),
#  (1951, 0),
#  (1952, 0),
#  (1953, 0),
#  (1954, 0),
#  (1955, 66),
#  (1956, 0),
#  (1957, 0),
#  (1958, 0),
#  (1959, 0),
#  (1960, 745),
#  (1961, 27),
#  (1962, 0),
#  (1963, 0),
#  (1964, 7),
#  (1965, 760),
#  (1966, 95),
#  (1967, 57),
#  (1968, 116),
#  (1969, 350),
#  (1970, 1444),
#  (1971, 75),
#  (1972, 364),
#  (1973, 34),
#  (1974, 350),
#  (1975, 3922),
#  (1976, 972),
#  (1977, 616),
#  (1978, 912),
#  (1979, 361),
#  (1980, 1528),
#  (1981, 644),
#  (1982, 448),
#  (1983, 333),
#  (1984, 666),
#  (1985, 990),
#  (1986, 238),
#  (1987, 771),
#  (1988, 266),
#  (1989, 307),
#  (1990, 433),
#  (1991, 146),
#  (1992, 226),
#  (1993, 161),
#  (1994, 288),
#  (1995, 781),
#  (1996, 385),
#  (1997, 238),
#  (1998, 220),
#  (1999, 603),
#  (2000, 461),
#  (2001, 1626),
#  (2002, 341),
#  (2003, 352),
#  (2004, 352),
#  (2005, 450),
#  (2006, 616),
#  (2007, 155),
#  (2008, 219),
#  (2009, 696),
#  (2010, 467),
#  (2011, 530),
#  (2012, 338),
#  (2013, 335),
# ...

# %%
annees_mandat = [(1950,1959),(1959,1965), (1965,1983), (1983,1994), (1995,2014), (2014,2017)]
nom_maire = ["Leon Martin", "Albert Michallon", "Hubert Dubedout", "Michel Destot", "Alain Carignon", "Eric Piolle"]
somme_dict = {}

for i in range(len(annees_mandat)):
    mandat = annees_mandat[i]
    somme_dict[ nom_maire[i] ] = 0
    for annee in range(*mandat):
        somme_dict[ nom_maire[i] ] += list_annee.count(str(annee))
        
print(somme_dict)
# Out:
# {'Leon Martin': 488, 'Albert Michallon': 779, 'Hubert Dubedout': 13048, 'Michel Destot': 4537, 'Alain Carignon': 9165, 'Eric Piolle': 2224}

# %%
list_genre_botanique=[]
for ligne in data:
    list_genre_botanique.append(ligne[13])

# %%
liste_anne_genre_botanique=list(zip(list_annee,list_genre_botanique))
liste_anne_genre_botanique
# Out:
# [('ANNEEDEPLANTATION', 'GENRE_BOTA'),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('2017', ''),
#  ('2017', ''),
#  ('2017', ''),
#  ('2017', ''),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', ''),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', ''),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', 'Platanus'),
#  ('2017', ''),
#  ('2017', ''),
#  ('2017', ''),
#  ('2017', ''),
#  ('2017', ''),
# ...

# %%
compte_arbre_vide=list_genre_botanique.count('')
compte_arbre_vide
# Out:
# 515

# %%
import matplotlib.pyplot as plt 
x=dico_anne.keys()
y=dico_anne.values()

plt.xlabel('year')
plt.ylabel("""nb d'arbres""")
plt.bar(x,y)
plt.grid()
plt.show()

# %%
liste_sorted_anne_genre_botanique=sorted(liste_anne_genre_botanique, key=lambda x: x[0])
liste_sorted_anne_genre_botanique
# Out:
# [('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
# ...
